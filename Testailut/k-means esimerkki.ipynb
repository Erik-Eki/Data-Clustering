# %% [markdown]
# ## Exercise 5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)

# %%
from sklearn import datasets
n_samples = 1500
data = datasets.make_circles(n_samples=n_samples, factor=.5, noise=.05)[0]
plt.scatter(data[:,0], data[:,1])
plt.show()

# %%
plt.hist(data[:,0])
plt.show()

# %%
print(len(data))
data[:,0]
# Out:
# 1500
# array([-0.67799938,  0.93143746,  0.54829131, ..., -0.34518816,
#         0.01719727,  0.91377877])

# %% [markdown]
# ## Exercise 6

# %%
from sklearn.cluster import KMeans

# %%
ideal_k = []
for i in range(1,21):
    est_kmeans = KMeans(n_clusters=i)
    est_kmeans.fit(data)
    
    ideal_k.append([i,est_kmeans.inertia_])

# %%
ideal_k = np.array(ideal_k)

# %%
plt.plot(ideal_k[:,0],ideal_k[:,1])
plt.show()

# %%
data
# Out:
# array([[-0.67799938, -0.69875698],
#        [ 0.93143746,  0.19139133],
#        [ 0.54829131, -0.00601715],
#        ...,
#        [-0.34518816, -0.35804797],
#        [ 0.01719727, -0.94513802],
#        [ 0.91377877, -0.59884164]])

# %% [markdown]
# A number of cluster of 5 was selected

# %%
est_kmeans = KMeans(n_clusters=5)
est_kmeans.fit(data)
pred_kmeans = est_kmeans.predict(data)

# %%
plt.scatter(data[:,0], data[:,1], c=pred_kmeans)
plt.show()
